# %%
# a MLP learns a vector field morphing random points into shape(name of loved one or heart)
# vis the rectification optimization process of vec field too

# encode her name in a neural network(aida) and upload it to your brain
# and live happly ever after in the clouds
